# %% [markdown]
# <a href="https://colab.research.google.com/github/RafliArafat/PCVK_semester-5/blob/main/week1_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://th.bing.com/th/id/OIP.YGZ8maalsglQKp7J9CVXFgHaHa?w=190&h=190&c=7&r=0&o=5&dpr=1.3&pid=1.7",
        "https://th.bing.com/th/id/OIP.6rRrDVxnPx_U3Bij7PsQSQHaFF?w=258&h=180&c=7&r=0&o=5&dpr=1.3&pid=1.7"]

# tugas
image = io.imread(urls[3])
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print ("tinggi x lebar : ",tinggi," x ",lebar)
# garis vertikal
# for x in range (tinggi):
#   image_3[x,int((lebar)/2)] = [255,255,255]

# garis menyilang
# for y in range (min(tinggi, lebar)):
#   image_3[y,y] = [255,255,255]

# for y in range (min(tinggi, lebar)):
#   image_3[tinggi - 1 - y, y] = [255,255,255]

# bisa jadi satu
# for y in range (min(tinggi, lebar)):
#   image_3[y,lebar/tinggi*y] = [255,255,255]
#   image_3[tinggi - 1 - y, y] = [255,255,255]

# garis ditengah
# for y in range (20, 90):
#   image_3[int((tinggi)/2),y] = [255,255,255]

# kotak kecil
# for y in range(93,210):
#   for x in range(75,82):
#     image_3[x,y] = [255,255,255]

# KTP
# kelompok 1
for y in range(90,217):
  for x in range(58,70):
    image_3[x,y] = [234,254,214]
for y in range(93,210):
  for x in range(75,82):
    image_3[x,y] = [90,90,90]
# kelompok 2
for y in range(93,190):
  for x in range(85,92):
    image_3[x,y] = [130,130,200]
for y in range(93,133):
  for x in range(95,102):
    image_3[x,y] = [200,214,21]
# kelompok 3
for y in range(215,228):
  for x in range(95,102):
    image_3[x,y] = [170,241,81]
for y in range(260,295):
  for x in range(191,217):
    image_3[x,y] = [70,83,90]
# kelompok 4
for y in range(93,170):
  for x in range(105,112):
    image_3[x,y] = [255,1,107]
for y in range(93,155):
  for x in range(132,140):
    image_3[x,y] = [198,146,43]
# kelompok 5
for y in range(93,130):
  for x in range(142,150):
    image_3[x,y] = [123,255,255]
for y in range(93,125):
  for x in range(152,160):
    image_3[x,y] = [255,42,210]
# kelompok 6
for y in range(93,177):
  for x in range(162,170):
    image_3[x,y] = [0,0,0]
for y in range(93,115):
  for x in range(172,180):
    image_3[x,y] = [222,111,66]
# kelompok 7
for y in range(93,160):
  for x in range(182,190):
    image_3[x,y] = [255,0,0]
for y in range(242,320):
  for x in range(66,165):
    image_3[x,y] = [0,0,255]
# kelompok 8
for y in range(250,305):
  for x in range(167,175):
    image_3[x,y] = [0,255,0]
for y in range(257,298):
  for x in range(179,187):
    image_3[x,y] = [12,120,255]
# kelompok 9
for y in range(110,230):
  for x in range(17,28):
    image_3[x,y] = [255,27,83]
for y in range(125,210):
  for x in range(33,45):
    image_3[x,y] = [120,255,27]
# kelompok 10
for y in range(93,128):
  for x in range(114,121):
    image_3[x,y] = [255,255,255]
for y in range(93,170):
  for x in range(124,131):
    image_3[x,y] = [255,255,255]
# final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(image_3)
# praktikum
# for url in urls:
#   image = io.imread(url)
#   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#   image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#   image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  # langkah 2
  # final_frame = cv.hconcat((image, image_2))
  # cv2_imshow(final_frame)
  # langkah 3
  # tinggi = image_2.shape[0]
  # lebar = image_2.shape[1]
  # print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
  # cv2_imshow(image_2)
  # langkah 4
  # for y in range (lebar):
  #   image_3[int((tinggi)/2),y] = [255,255,255]

  # final_frame = cv.hconcat((image_2, image_3))
  # cv2_imshow(final_frame)
  # print('\n')
# Out:
# tinggi x lebar :  234  x  335
# <PIL.Image.Image image mode=RGB size=335x234>
